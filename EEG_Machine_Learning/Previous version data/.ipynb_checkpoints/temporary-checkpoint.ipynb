# %%
import os
import matplotlib as mpl
import matplotlib.pylab as plt
import itertools
import csv , codecs
import glob
from PIL import Image
import numpy as np
import pandas as pd
import openpyxl
from openpyxl import Workbook
from openpyxl import load_workbook
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
def warn(*args, **kwargs): pass
import warnings
warnings.warn = warn
from sklearn import decomposition
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, log_loss
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA

# %%
data_dir = "./EEG_data/"

# %% [markdown]
# ## CSV 파일 생성 함수

# %%
def EEG_data_csv(data_dir):
    
    # Kinds of Power 입력
    file_list = os.listdir(data_dir)
    file_list.sort()
       
    global kinds_of_power
    kinds_of_power = "Relative"
    
    excel_dir = "./EEG_data" + '/' + kinds_of_power
    excel_list = sorted(glob.glob(excel_dir+'/[!~]*.xlsx'))
    
    # EEG_csv_data 디렉토리 생성
    csv_dir = "./EEG_csv_data"
    if not os.path.isdir(csv_dir):
        os.mkdir(csv_dir)
    
    Abs_dir ="./EEG_csv_data/Abs"
    Relative_dir = "./EEG_csv_data/Relative"
    
    if not os.path.isdir(Abs_dir):
        os.mkdir(Abs_dir)
    if not os.path.isdir(Relative_dir):
        os.mkdir(Relative_dir)
    
    book = Workbook()
    sheet = book.active
    
    # x축,y축 생성
    for i in range (1,21) :
        if i < 10 :
            sheet['A'+str(i+1)] = 'S0'+str(i)
        if i == 10 :
            sheet['A'+str(i+1)] = 'S'+str(10)
        if i > 10 :
            sheet['A'+str(i+1)] = 'S'+str(i)
            
    for j in range (0,12):
        for i in range(1,33):
            sheet.cell(row=1, column=160*j+i+1).value = 'ACh' + str(i)
            sheet.cell(row=1, column=160*j+i+33).value = 'BCh' + str(i)
            sheet.cell(row=1, column=160*j+i+65).value = 'DCh' + str(i)
            sheet.cell(row=1, column=160*j+i+97).value = 'GCh' + str(i)
            sheet.cell(row=1, column=160*j+i+129).value = 'TCh' + str(i)

    # 파일을 순차적으로 열어서 셀 영역을 복사
    # j: 엑셀 파일의 수, k: 각 엑셀 파일 당 시트의 수, n: task의 수, l: subject의 수, m: ch1-ch32

    for j in range(0,5):
        wb = openpyxl.load_workbook(excel_list[j], data_only=True)
        wb_sheet = wb.sheetnames
        for k in range(0,12):
            source = wb[wb_sheet[k]]
            for l in range(2, 22):
                for m in range(2, 34):
                    sheet.cell(row=l,column=160*k+m+32*j).value = source.cell(row=l,column=m).value

    # EEG_csv_data 디렉토리에 csv 파일로 저장
    if kinds_of_power == "Abs":
        with open(Abs_dir + str('/') +'Abs_Merged.csv', 'w', newline="") as f:
            c = csv.writer(f)
            for r in sheet.rows:
                c.writerow([cell.value for cell in r])
    elif kinds_of_power == "Relative":
        with open(Relative_dir + str('/') +'Relative_Merged.csv', 'w', newline="") as f:
            c = csv.writer(f)
            for r in sheet.rows:
                c.writerow([cell.value for cell in r])

# %% [markdown]
# ## CSV 파일에서 Pandas dataframe으로 가져오는 함수

# %%
EEG_data_csv(data_dir)

# %% [markdown]
# ### task 0 1 2 : 1-back,  2-back,  rest
#
# ### eye 0  1    : close eye,     open eye
#
# ### respiratory 0 1 2 : mouse, nose, O2

# %%
def dataset_csv_3():
    normalize_power = str(input("Relative, Abs :"))
    excel_dir = "./EEG_data" + '/' + normalize_power
    excel_list = sorted(glob.glob(excel_dir+'/[!~]*.xlsx'))
    
    subject = int(input("subject :"))
    book = Workbook()
    sheet = book.active
    sheet.cell(row=1, column=161).value = 'target'
 
    # x축 생성   
    for i in range(1,33):
        sheet.cell(row=1, column=i).value = 'ACh' + str(i)
        sheet.cell(row=1, column=i+32).value = 'BCh' + str(i)
        sheet.cell(row=1, column=i+64).value = 'DCh' + str(i)
        sheet.cell(row=1, column=i+96).value = 'GCh' + str(i)
        sheet.cell(row=1, column=i+128).value = 'TCh' + str(i)
        
    # 파일을 순차적으로 열어서 셀 영역을 복사
    for j in range(0,5):
        wb = openpyxl.load_workbook(excel_list[j], data_only=True)
        wb_sheet = wb.sheetnames
        for k in range(0,12):
            source = wb[wb_sheet[k]]
            for l in range(2, 22):
                for m in range(2, 34):
                    sheet.cell(row=20*k+l,column=32*j+m-1).value = source.cell(row=l,column=m).value
        

    with open('./dataset_eeg_3.csv', 'w', newline="") as f:
        c = csv.writer(f)
        for r in sheet.rows:
            c.writerow([cell.value for cell in r])
            
    df = pd.read_csv('./dataset_eeg_3.csv')
    df[df =='                      NaN'] =np.nan
    df = df.fillna(0.0).astype('float64')
    pd.options.mode.chained_assignment = None
#1-back mouse, nose, o2
    df["target"][0*subject:1*subject] = "0" #0:20
    df["target"][1*subject:2*subject] = "1" #21:40
    df["target"][2*subject:3*subject] = "2" #41:60
#2-back mouse, nose, o2
    df["target"][3*subject:4*subject] = "0" #60:80
    df["target"][4*subject:5*subject] = "1" #80:100
    df["target"][5*subject:6*subject] = "2" #100:120
#rest close eye mouse, nose, o2
    df["target"][6*subject:7*subject] = "0" #120:140
    df["target"][7*subject:8*subject] = "1" #140:160
    df["target"][8*subject:9*subject] = "2" #160:180
#rest open eye mouse, nose, o2
    df["target"][9*subject:10*subject] = "0" #180:200
    df["target"][10*subject:11*subject] = "1" #200:220
    df["target"][11*subject:12*subject] = "2" #220:240
    df.astype('float64')
    df.to_csv('./dataset_eeg_3.csv')
    
    return df

# %%
eeg_data_3 = dataset_csv_3()
# Out:
# Relative, Abs :Relative
# subject :20

# %%
eeg_data_3
# Out:
#           ACh1       ACh2       ACh3       ACh4       ACh5       ACh6  \
# 0     4.512153   2.236848  16.237565   8.485316  23.868040   8.095887
# 1     4.539769   4.310226   4.959007   3.965357   7.222414   5.466902
# 2     9.876811   9.070304   3.572186   4.272411  12.559673  19.156709
# 3     4.224107   6.190282   8.670873   8.869054  25.241644  20.749929
# 4    18.441049  19.286110   8.901129  12.888736   7.272771  15.879294
# ..         ...        ...        ...        ...        ...        ...
# 235   9.377716   6.913374   5.995995   4.562073   6.141009   6.275420
# 236  11.906533  10.057115  11.180124  11.478218  14.621087  16.359638
# 237  10.335814   8.589677  13.796878  13.048695  25.629270  24.416874
# 238  14.781336  13.040448   5.557476   4.101700  19.404795  10.489655
# 239   0.816538   1.050772   0.163984   0.208546   0.376742   0.538038
#
#           ACh7       ACh8       ACh9      ACh10  ...      TCh24      TCh25  \
# 0    61.092520  63.790479  68.686679  69.925212  ...   8.735276   0.828638
# 1    16.751086  19.945360  30.425709  24.128985  ...  18.794290   9.741533
# 2    26.778865  17.134912  53.187562  49.574373  ...  11.408656   6.724140
# 3    40.968150  43.190059  42.509827  41.379676  ...  10.493111   4.743475
# 4    23.182914  38.046045  29.140603  32.524267  ...  14.825606  16.428830
# ..         ...        ...        ...        ...  ...        ...        ...
# 235  17.190073  19.530794  29.798448  27.170256  ...   5.781882  11.865520
# 236  26.560596  24.297633  30.679741  26.798845  ...  16.024479   6.548399
# 237  33.204969  34.318945  29.184918  28.485295  ...  24.964200  19.061720
# 238  27.480708  24.014191  32.643752  30.794355  ...  20.821745   9.054677
# 239   5.100128   1.964278   7.376851   4.903818  ...   0.886371   0.319325
#
#          TCh26      TCh27      TCh28      TCh29      TCh30      TCh31  \
# 0     1.010004   1.778969   6.435780  14.978180  11.507832  11.162954
# 1     7.106003  10.521237   8.559514  18.069939  15.457455  22.764836
# 2     8.721257  10.193054   2.678986  11.522934  11.118133  11.282202
# 3     5.994422   2.769252   5.845854  11.149340  12.461344  12.748985
# 4    15.406232  16.088470  17.454960  18.750681  17.095190  13.764769
# ..         ...        ...        ...        ...        ...        ...
# 235  10.328138  10.171290  11.796915  15.583215  16.539841  15.194092
# 236   6.806564  10.569691  14.455136  15.406702  16.142647  14.712165
# 237  18.617480  16.023406  20.075270  26.804320  25.657373  24.098649
# 238  14.631369  11.264431  17.292341  19.074393  22.937862  23.429094
# 239   0.393430   2.912542   0.339576   3.356003   2.804871   5.997765
#
#          TCh32  target
# 0     9.491918       0
# 1    22.393518       0
# 2    10.760432       0
# 3    11.845096       0
# 4    13.443134       0
# ..         ...     ...
# 235  14.108681       2
# 236  14.551317       2
# 237  19.401579       2
# 238  12.989213       2
# 239   6.470478       2
#
# [240 rows x 161 columns]

# %%
ds_train = {}
ds_test = {}
##########################################################
# train: rest_close_eye mouse, nose
#test :  rest_close_eye mouse, nose
ds_train['close_eye_rest']=eeg_data_3.iloc[120:160]
ds_test['close_eye_rest']=eeg_data_3.iloc[120:160]

# train: rest_close_eye mouse, nose
#test :  rest mouse, nose
ds_train['close_eye_rest']=eeg_data_3.iloc[120:160]
ds_test['open_eye_rest']=eeg_data_3.iloc[180:220]

# train: rest_close_eye mouse, nose
#test :  1-back mouse, nose
ds_train['close_eye_rest']=eeg_data_3.iloc[120:160]
ds_test['1back']=eeg_data_3.iloc[0:40]

# train: rest_close_eye mouse, nose
# test :  2-back mouse, nose
ds_train['close_eye_rest']=eeg_data_3.iloc[120:160]
ds_test['2back']=eeg_data_3.iloc[60:100]


# train: rest_open_eye mouse, nose
#test :  rest_close_eye mouse
ds_train['open_eye_rest']=eeg_data_3.iloc[180:220]
ds_test['open_eye_rest_mouse']=eeg_data_3.iloc[180:200]

# train: rest_open_eye mouse, nose
#test :  rest mouse
ds_train['open_eye_rest']=eeg_data_3.iloc[180:220]
ds_test['close_eye_rest_mouse']=eeg_data_3.iloc[120:140]



# train: rest_open_eye mouse, nose
#test :  rest_close_eye mouse
ds_train['open_eye_rest']=eeg_data_3.iloc[180:220]
ds_test['open_eye_rest_nose']=eeg_data_3.iloc[200:220]

# train: rest_open_eye mouse, nose
#test :  rest mouse
ds_train['open_eye_rest']=eeg_data_3.iloc[180:220]
ds_test['close_eye_rest_nose']=eeg_data_3.iloc[140:160]





# train: rest_open_eye mouse, nose
#test :  1-back mouse
ds_train['open_eye_rest']=eeg_data_3.iloc[180:220]
ds_test['1back_mouse']=eeg_data_3.iloc[0:20]

# train: rest_open_eye mouse, nose
# test :  2-back mouse
ds_train['open_eye_rest']=eeg_data_3.iloc[180:220]
ds_test['2back_mouse']=eeg_data_3.iloc[60:80]

# train: rest_open_eye mouse, nose
#test :  1-back nose
ds_train['open_eye_rest']=eeg_data_3.iloc[180:220]
ds_test['1back_nose']=eeg_data_3.iloc[20:40]

# train: rest_open_eye mouse, nose
# test :  2-back nose
ds_train['open_eye_rest']=eeg_data_3.iloc[180:220]
ds_test['2back_nose']=eeg_data_3.iloc[80:100]


# train: rest(open_eye, close_eye)
ds_train['rest']=eeg_data_3.iloc[120:160].append(eeg_data_3.iloc[180:220])



# test :  open_eye O2
ds_test['open_eye_rest_O2']=eeg_data_3.iloc[220:240]

# test :  close_eye O2
ds_test['close_eye_rest_O2']=eeg_data_3.iloc[160:180]

# test :  1-back O2
ds_test['1back_O2']=eeg_data_3.iloc[40:60]

# test :  2-back O2
ds_test['2back_O2']=eeg_data_3.iloc[100:120]









##########################################################

# # train : open_eye + 1-back
# ds_train['open_eye_1back']= eeg_data_3.iloc[0:40]
# ds_test['open_eye_1back'] = eeg_data_3.iloc[40:60]

# # train : open_eye + 2-back
# ds_train['open_eye_2back']= eeg_data_3.iloc[60:100]
# ds_test['open_eye_2back']= eeg_data_3.iloc[100:120]

# # train : open_eye + rest 
# ds_train['open_eye_rest']= eeg_data_3.iloc[180:220]
# ds_test['open_eye_rest']= eeg_data_3.iloc[220:240]

# # train : close_eye + rest
# ds_train['close_eye_rest']=eeg_data_3.iloc[120:160]
# ds_test['close_eye_rest']=eeg_data_3.iloc[160:180]

# train : total
ds_train['total']=eeg_data_3.iloc[0:40].append( eeg_data_3.iloc[60:100]).append(eeg_data_3.iloc[120:160]).append(eeg_data_3.iloc[180:220])
ds_test['total']= eeg_data_3.iloc[40:60].append( eeg_data_3.iloc[100:120]).append(eeg_data_3.iloc[160:180]).append(eeg_data_3.iloc[220:240])

# %%
def LDA_M_N_O2 (tasks, k_parameter, num_iter):

#     for mode in ['no_lda','lda']:
    for mode in ['lda']:
        for task_train,task_test in tasks:

            print('-------------------')
            print('training:{}/test:{}/mode:{}'.format(task_train,task_test,mode))
            train_3 = ds_train[task_train]
            test_3  = ds_test[task_test]

            X = np.array(train_3.iloc[:,0:-1])
            Y = np.array(train_3['target'])

            rnd_clf = RandomForestClassifier(n_estimators=1000,max_depth= None, n_jobs=-1,class_weight="balanced")

            all_scores = []
            Mouse = 0
            Nose = 0
            for idx in range(num_iter):
                skf = StratifiedKFold(n_splits=k_parameter, shuffle=True)
                skf.get_n_splits(X,Y)

                for train_index, test_index in skf.split(X,Y):

                    X_final = X
                    lda = LinearDiscriminantAnalysis(n_components=1)
                    if(mode == 'lda') : 
                        lda.fit(X,Y)
                        X_final = lda.transform(X)
                    

                    rnd_clf.fit(X_final[train_index], Y[train_index])
                    val_mae = rnd_clf.score(X_final[test_index],Y[test_index])
                    all_scores.append(val_mae)

                    test = np.array(test_3.iloc[:,0:-1])
                    if mode == 'lda':
                        test = lda.transform(test)

                    aaa = rnd_clf.predict(test)

                    Mouse = Mouse+np.count_nonzero(aaa=='0')
                    Nose = Nose+ np.count_nonzero(aaa=='1')

            print('model_score:{}'.format(np.mean(all_scores)))
            print('mouse:{}({:.2}), nose:{}({:.2}) / total:{}'.format(Mouse,Mouse/(Mouse+Nose),Nose,Nose/(Mouse+Nose),(Mouse+Nose)))

# %%
def PCA_M_N_O2 (tasks, k_parameter, num_iter):

#     for mode in ['no_lda','lda']:
    for mode in ['pca']:
        for task_train,task_test in tasks:

            print('-------------------')
            print('training:{}/test:{}/mode:{}'.format(task_train,task_test,mode))
            train_3 = ds_train[task_train]
            test_3  = ds_test[task_test]

            X = np.array(train_3.iloc[:,0:-1])
            Y = np.array(train_3['target'])

#             rnd_clf = RandomForestClassifier(n_estimators=1000,max_depth= None, n_jobs=-1,class_weight="balanced" )
            rnd_clf = RandomForestClassifier(n_estimators=1000,max_features= 160,n_jobs=-1 )

            all_scores = []
            Mouse = 0
            Nose = 0
            for idx in range(num_iter):
                skf = StratifiedKFold(n_splits=k_parameter, shuffle=True)
                skf.get_n_splits(X,Y)

                for train_index, test_index in skf.split(X,Y):

                    X_final = X
                    pca = PCA(n_components=0.8)
                    if(mode == 'pca') : 
                        pca.fit(X,Y)
#                         X_final = pca.transform(X)
                        X_final = X
                    

                    rnd_clf.fit(X_final[train_index], Y[train_index])
                    val_mae = rnd_clf.score(X_final[test_index],Y[test_index])
                    all_scores.append(val_mae)

                    test = np.array(test_3.iloc[:,0:-1])
                    if mode == 'pca':
                        pass
#                         test = pca.transform(test)

                    aaa = rnd_clf.predict(test)

                    Mouse = Mouse+np.count_nonzero(aaa=='0')
                    Nose = Nose+ np.count_nonzero(aaa=='1')

            print('model_score:{}'.format(np.mean(all_scores)))
            print('mouse:{}({:.2}), nose:{}({:.2}) / total:{}'.format(Mouse,Mouse/(Mouse+Nose),Nose,Nose/(Mouse+Nose),(Mouse+Nose)))

# %%
tasks5 = [
     ('close_eye_rest','close_eye_rest'),
     ('close_eye_rest','open_eye_rest'),
     ('close_eye_rest','open_eye_1back'),
     ('close_eye_rest','open_eye_2back'),
     ('close_eye_rest','total')
 ]


#tasks6 = [
#     ('close_eye_rest','open_eye_rest'),
#     ('close_eye_rest','open_eye_1back'),
#     ('close_eye_rest','open_eye_2back'),
# ]


tasks = [
     ('close_eye_rest','close_eye_rest'),
     ('close_eye_rest','open_eye_rest'),
     ('close_eye_rest','1back'),
     ('close_eye_rest','2back'),
 ]


tasks2 = [
    ('close_eye_rest','open_eye_rest_mouse'),
    ('close_eye_rest','open_eye_rest_nose'),
    ('close_eye_rest','close_eye_rest_mouse'),
    ('close_eye_rest','close_eye_rest_nose'),
     ('close_eye_rest','1back_mouse'),
     ('close_eye_rest','1back_nose'),
     ('close_eye_rest','2back_mouse'),
     ('close_eye_rest','2back_nose'),
 ]


tasks3 = [
    ('total','open_eye_rest_mouse'),
    ('total','open_eye_rest_nose'),
    ('total','close_eye_rest_mouse'),
    ('total','close_eye_rest_nose'),
     ('total','1back_mouse'),
     ('total','1back_nose'),
     ('total','2back_mouse'),
     ('total','2back_nose'),
 ]



tasks4 = [
    ('total','open_eye_rest_O2'),
    
    ('total','close_eye_rest_O2'),
    
     ('total','1back_O2'),
    
     ('total','2back_O2'),
    
    
    
 ]

# %%
M_N_O2(tasks5,k_parameter = 10,num_iter = 1)
# Out:
# -------------------
# training:close_eye_rest/test:close_eye_rest/mode:no_lda
# model_score:0.1
# mouse:80(0.4), nose:120(0.6) / total:200
# -------------------
# training:close_eye_rest/test:open_eye_rest/mode:no_lda
# model_score:0.175
# mouse:71(0.35), nose:129(0.65) / total:200
# -------------------
# training:close_eye_rest/test:open_eye_1back/mode:no_lda
# model_score:0.175
# mouse:39(0.2), nose:161(0.81) / total:200
# -------------------
# training:close_eye_rest/test:open_eye_2back/mode:no_lda
# model_score:0.15
# mouse:45(0.23), nose:155(0.78) / total:200
# -------------------
# training:close_eye_rest/test:total/mode:no_lda
# model_score:0.175
# mouse:242(0.3), nose:558(0.7) / total:800
# -------------------
# training:close_eye_rest/test:close_eye_rest/mode:lda
# model_score:0.95
# mouse:101(0.51), nose:99(0.49) / total:200
# -------------------
# training:close_eye_rest/test:open_eye_rest/mode:lda
# model_score:0.975
# mouse:100(0.5), nose:100(0.5) / total:200
# -------------------
# training:close_eye_rest/test:open_eye_1back/mode:lda
# model_score:0.95
# mouse:71(0.35), nose:129(0.65) / total:200
# -------------------
# training:close_eye_rest/test:open_eye_2back/mode:lda
# model_score:0.95
# mouse:51(0.26), nose:149(0.74) / total:200
# -------------------
# training:close_eye_rest/test:total/mode:lda
# model_score:0.95
# mouse:323(0.4), nose:477(0.6) / total:800

# %%
M_N_O2(tasks,k_parameter = 10,num_iter = 10)
# Out:
# -------------------
# training:close_eye_rest/test:close_eye_rest/mode:lda
# model_score:0.9475
# mouse:2001(0.5), nose:1999(0.5) / total:4000
# -------------------
# training:close_eye_rest/test:open_eye_rest/mode:lda
# model_score:0.955
# mouse:1100(0.28), nose:2900(0.72) / total:4000
# -------------------
# training:close_eye_rest/test:1back/mode:lda
# model_score:0.945
# mouse:1023(0.26), nose:2977(0.74) / total:4000
# -------------------
# training:close_eye_rest/test:2back/mode:lda
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-0fa95044e846> in <module>
# ----> 1 M_N_O2(tasks,k_parameter = 10,num_iter = 10)
#
# <ipython-input-39-f62c63a1a4fb> in M_N_O2(tasks, k_parameter, num_iter)
#      31
#      32                     rnd_clf.fit(X_final[train_index], Y[train_index])
# ---> 33                     val_mae = rnd_clf.score(X_final[test_index],Y[test_index])
#      34                     all_scores.append(val_mae)
#      35
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     355         """
#     356         from .metrics import accuracy_score
# --> 357         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     358
#     359
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in predict(self, X)
#     543             The predicted classes.
#     544         """
# --> 545         proba = self.predict_proba(X)
#     546
#     547         if self.n_outputs_ == 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in predict_proba(self, X)
#     599             delayed(_accumulate_prediction)(e.predict_proba, X, all_proba,
#     600                                             lock)
# --> 601             for e in self.estimators_)
#     602
#     603         for proba in all_proba:
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~\Anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
M_N_O2(tasks2,k_parameter = 10,num_iter = 1)
# Out:
# -------------------
# training:open_eye_rest/test:open_eye_rest_mouse/mode:lda
# model_score:0.875
# mouse:197(0.98), nose:3(0.015) / total:200
# -------------------
# training:open_eye_rest/test:open_eye_rest_nose/mode:lda
# model_score:0.875
# mouse:2(0.01), nose:198(0.99) / total:200
# -------------------
# training:open_eye_rest/test:close_eye_rest_mouse/mode:lda
# model_score:0.875
# mouse:111(0.56), nose:89(0.45) / total:200
# -------------------
# training:open_eye_rest/test:close_eye_rest_nose/mode:lda
# model_score:0.875
# mouse:111(0.56), nose:89(0.45) / total:200
# -------------------
# training:open_eye_rest/test:1back_mouse/mode:lda
# model_score:0.825
# mouse:86(0.43), nose:114(0.57) / total:200
# -------------------
# training:open_eye_rest/test:1back_nose/mode:lda
# model_score:0.9
# mouse:91(0.46), nose:109(0.55) / total:200
# -------------------
# training:open_eye_rest/test:2back_mouse/mode:lda
# model_score:0.875
# mouse:72(0.36), nose:128(0.64) / total:200
# -------------------
# training:open_eye_rest/test:2back_nose/mode:lda
# model_score:0.875
# mouse:58(0.29), nose:142(0.71) / total:200

# %%
PCA_M_N_O2(tasks2,k_parameter = 10,num_iter = 1)
# Out:
# -------------------
# training:close_eye_rest/test:open_eye_rest_mouse/mode:pca
# model_score:0.35
# mouse:110(0.55), nose:90(0.45) / total:200
# -------------------
# training:close_eye_rest/test:open_eye_rest_nose/mode:pca
# model_score:0.3
# mouse:101(0.51), nose:99(0.49) / total:200
# -------------------
# training:close_eye_rest/test:close_eye_rest_mouse/mode:pca
# model_score:0.35
# mouse:186(0.93), nose:14(0.07) / total:200
# -------------------
# training:close_eye_rest/test:close_eye_rest_nose/mode:pca
# model_score:0.4
# mouse:12(0.06), nose:188(0.94) / total:200
# -------------------
# training:close_eye_rest/test:1back_mouse/mode:pca
# model_score:0.375
# mouse:108(0.54), nose:92(0.46) / total:200
# -------------------
# training:close_eye_rest/test:1back_nose/mode:pca
# model_score:0.375
# mouse:95(0.47), nose:105(0.53) / total:200
# -------------------
# training:close_eye_rest/test:2back_mouse/mode:pca
# model_score:0.325
# mouse:82(0.41), nose:118(0.59) / total:200
# -------------------
# training:close_eye_rest/test:2back_nose/mode:pca
# model_score:0.325
# mouse:86(0.43), nose:114(0.57) / total:200

# %%
PCA_M_N_O2(tasks3,k_parameter = 10,num_iter = 1)
# Out:
# -------------------
# training:rest/test:open_eye_rest_mouse/mode:pca
# model_score:0.5
# mouse:189(0.94), nose:11(0.055) / total:200
# -------------------
# training:rest/test:open_eye_rest_nose/mode:pca
# model_score:0.525
# mouse:14(0.07), nose:186(0.93) / total:200
# -------------------
# training:rest/test:close_eye_rest_mouse/mode:pca
# model_score:0.4625
# mouse:188(0.94), nose:12(0.06) / total:200
# -------------------
# training:rest/test:close_eye_rest_nose/mode:pca
# model_score:0.5
# mouse:11(0.055), nose:189(0.94) / total:200
# -------------------
# training:rest/test:1back_mouse/mode:pca
# model_score:0.475
# mouse:118(0.59), nose:82(0.41) / total:200
# -------------------
# training:rest/test:1back_nose/mode:pca
# model_score:0.475
# mouse:95(0.47), nose:105(0.53) / total:200
# -------------------
# training:rest/test:2back_mouse/mode:pca
# model_score:0.5
# mouse:101(0.51), nose:99(0.49) / total:200
# -------------------
# training:rest/test:2back_nose/mode:pca
# model_score:0.525
# mouse:83(0.41), nose:117(0.58) / total:200

# %%
LDA_M_N_O2(tasks3,k_parameter = 10,num_iter = 1)
# Out:
# -------------------
# training:rest/test:open_eye_rest_mouse/mode:lda
# model_score:1.0
# mouse:200(1.0), nose:0(0.0) / total:200
# -------------------
# training:rest/test:open_eye_rest_nose/mode:lda
# model_score:1.0
# mouse:0(0.0), nose:200(1.0) / total:200
# -------------------
# training:rest/test:close_eye_rest_mouse/mode:lda
# model_score:1.0
# mouse:200(1.0), nose:0(0.0) / total:200
# -------------------
# training:rest/test:close_eye_rest_nose/mode:lda
# model_score:1.0
# mouse:0(0.0), nose:200(1.0) / total:200
# -------------------
# training:rest/test:1back_mouse/mode:lda
# model_score:1.0
# mouse:150(0.75), nose:50(0.25) / total:200
# -------------------
# training:rest/test:1back_nose/mode:lda
# model_score:1.0
# mouse:120(0.6), nose:80(0.4) / total:200
# -------------------
# training:rest/test:2back_mouse/mode:lda
# model_score:1.0
# mouse:150(0.75), nose:50(0.25) / total:200
# -------------------
# training:rest/test:2back_nose/mode:lda
# model_score:1.0
# mouse:140(0.7), nose:60(0.3) / total:200

# %%
LDA_M_N_O2(tasks3,k_parameter = 10,num_iter = 1)
# Out:
# -------------------
# training:rest/test:open_eye_rest_mouse/mode:lda
# model_score:1.0
# mouse:200(1.0), nose:0(0.0) / total:200
# -------------------
# training:rest/test:open_eye_rest_nose/mode:lda
# model_score:1.0
# mouse:0(0.0), nose:200(1.0) / total:200
# -------------------
# training:rest/test:close_eye_rest_mouse/mode:lda
# model_score:1.0
# mouse:200(1.0), nose:0(0.0) / total:200
# -------------------
# training:rest/test:close_eye_rest_nose/mode:lda
# model_score:1.0
# mouse:0(0.0), nose:200(1.0) / total:200
# -------------------
# training:rest/test:1back_mouse/mode:lda
# model_score:1.0
# mouse:150(0.75), nose:50(0.25) / total:200
# -------------------
# training:rest/test:1back_nose/mode:lda
# model_score:1.0
# mouse:120(0.6), nose:80(0.4) / total:200
# -------------------
# training:rest/test:2back_mouse/mode:lda
# model_score:1.0
# mouse:150(0.75), nose:50(0.25) / total:200
# -------------------
# training:rest/test:2back_nose/mode:lda
# model_score:1.0
# mouse:140(0.7), nose:60(0.3) / total:200

# %%
PCA_M_N_O2(tasks3,k_parameter = 10,num_iter = 1)
# Out:
# -------------------
# training:total/test:open_eye_rest_mouse/mode:pca
# model_score:0.4375
# mouse:185(0.93), nose:15(0.075) / total:200
# -------------------
# training:total/test:open_eye_rest_nose/mode:pca
# model_score:0.46875
# mouse:9(0.045), nose:191(0.95) / total:200
# -------------------
# training:total/test:close_eye_rest_mouse/mode:pca
# model_score:0.4875
# mouse:189(0.94), nose:11(0.055) / total:200
# -------------------
# training:total/test:close_eye_rest_nose/mode:pca
# model_score:0.4875
# mouse:10(0.05), nose:190(0.95) / total:200
# -------------------
# training:total/test:1back_mouse/mode:pca
# model_score:0.45
# mouse:188(0.94), nose:12(0.06) / total:200
# -------------------
# training:total/test:1back_nose/mode:pca
# model_score:0.45625
# mouse:13(0.065), nose:187(0.94) / total:200
# -------------------
# training:total/test:2back_mouse/mode:pca
# model_score:0.48125
# mouse:197(0.98), nose:3(0.015) / total:200
# -------------------
# training:total/test:2back_nose/mode:pca
# model_score:0.45
# mouse:13(0.065), nose:187(0.94) / total:200

# %%
LDA_M_N_O2(tasks3,k_parameter = 10,num_iter = 1)
# Out:
# -------------------
# training:total/test:open_eye_rest_mouse/mode:lda
# model_score:0.95
# mouse:199(0.99), nose:1(0.005) / total:200
# -------------------
# training:total/test:open_eye_rest_nose/mode:lda
# model_score:0.94375
# mouse:2(0.01), nose:198(0.99) / total:200
# -------------------
# training:total/test:close_eye_rest_mouse/mode:lda
# model_score:0.94375
# mouse:198(0.99), nose:2(0.01) / total:200
# -------------------
# training:total/test:close_eye_rest_nose/mode:lda
# model_score:0.94375
# mouse:2(0.01), nose:198(0.99) / total:200
# -------------------
# training:total/test:1back_mouse/mode:lda
# model_score:0.94375
# mouse:199(0.99), nose:1(0.005) / total:200
# -------------------
# training:total/test:1back_nose/mode:lda
# model_score:0.94375
# mouse:1(0.005), nose:199(0.99) / total:200
# -------------------
# training:total/test:2back_mouse/mode:lda
# model_score:0.95
# mouse:200(1.0), nose:0(0.0) / total:200
# -------------------
# training:total/test:2back_nose/mode:lda
# model_score:0.93125
# mouse:0(0.0), nose:200(1.0) / total:200

# %%
LDA_M_N_O2(tasks4,k_parameter = 10,num_iter = 1)
# Out:
# -------------------
# training:total/test:open_eye_rest_O2/mode:lda
# model_score:0.93125
# mouse:99(0.49), nose:101(0.51) / total:200
# -------------------
# training:total/test:close_eye_rest_O2/mode:lda
# model_score:0.95
# mouse:50(0.25), nose:150(0.75) / total:200
# -------------------
# training:total/test:1back_O2/mode:lda
# model_score:0.94375
# mouse:110(0.55), nose:90(0.45) / total:200
# -------------------
# training:total/test:2back_O2/mode:lda
# model_score:0.94375
# mouse:100(0.5), nose:100(0.5) / total:200

# %%
PCA_M_N_O2(tasks4,k_parameter = 10,num_iter = 1)
# Out:
# -------------------
# training:total/test:open_eye_rest_O2/mode:pca
# model_score:0.325
# mouse:121(0.6), nose:79(0.4) / total:200
# -------------------
# training:total/test:close_eye_rest_O2/mode:pca
# model_score:0.35
# mouse:118(0.59), nose:82(0.41) / total:200
# -------------------
# training:total/test:1back_O2/mode:pca
# model_score:0.34375
# mouse:100(0.5), nose:100(0.5) / total:200
# -------------------
# training:total/test:2back_O2/mode:pca
